# %%
from Breaches import Breaches
# %matplotlib inline

# %%
b = Breaches(modelDays=2500, predictDays=None,
             dataSource=Breaches.getEnv("DATA_SOURCE"),
             apiKey=Breaches.getEnv("ALPHA_VANTAGE_API_KEY"))

# %%
b.open(path="breaches.json", forceRemote=False)
# Out:
# Get'in Capital One [COF] ... please wait
# Get'in Target [TGT] ... please wait
# Get'in Marriott [MAR] ... please wait
# Get'in Facebook [FB] ... please wait
# Get'in T-Mobile [TMUS] ... please wait
# Get'in Quest Diagnostics [DGX] ... please wait
# Get'in Under Armour [UAA] ... please wait
# Get'in Equifax [EFX] ... please wait
# Get'in Anthem [ANTM] ... please wait
# Get'in EBAY [EBAY] ... please wait

# %%
for i in b.IDs:
    b.predict(i)
# Out:
# Fit'in and predict'in COF ... please wait
# Fit'in and predict'in TGT ... please wait
# Fit'in and predict'in MAR ... please wait
# Fit'in and predict'in FB-2018 ... please wait
# Fit'in and predict'in TMUS ... please wait
# Fit'in and predict'in DGX ... please wait
# Fit'in and predict'in UAA ... please wait
# Fit'in and predict'in EFX ... please wait
# Fit'in and predict'in ANTM ... please wait
# Fit'in and predict'in EBAY ... please wait

# %%
b.showMeta()
# Out:
#       ID        Date  Price Before   Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#      COF  2019-07-29         97.65   96.50        90.81         85.50  Mon      True     Never     Never
#      TGT  2018-12-19         64.16   61.72        60.61         84.21  Wed      True         8        20
#      MAR  2018-11-30        120.99  114.23       118.70        128.82  Fri      True         4        87
#  FB-2018  2018-09-28        168.84  164.46       162.44        183.70  Fri      True       126       166
#     TMUS  2018-08-24         65.21   65.41        65.80         77.75  Fri     False       N/A       N/A
#      DGX  2018-05-03         98.10   97.69        98.23        100.60  Thu     False       N/A       N/A
#      UAA  2018-03-29         16.33   16.35        16.10         18.65  Thu      True         6        14
#      EFX  2017-09-07        138.08  139.38       120.35        143.74  Thu      True       685       685
#     ANTM  2015-02-04        127.94  128.58       128.19        275.54  Wed     False       N/A       N/A
#     EBAY   2014-5-21         21.70   21.67        21.51         40.02  Wed      True         3        69

# %%
for i in b.IDs:
    b.plot(i)
# Out:
#   ID        Date  Price Before  Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  COF  2019-07-29         97.65   96.5        90.81          85.5  Mon      True     Never     Never
#   ID        Date  Price Before  Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  TGT  2018-12-19         64.16  61.72        60.61         84.21  Wed      True         8        20
#   ID        Date  Price Before   Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  MAR  2018-11-30        120.99  114.23        118.7        128.82  Fri      True         4        87
#       ID        Date  Price Before   Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  FB-2018  2018-09-28        168.84  164.46       162.44         183.7  Fri      True       126       166
#    ID        Date  Price Before  Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  TMUS  2018-08-24         65.21  65.41         65.8         77.75  Fri     False       N/A       N/A
#   ID        Date  Price Before  Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  DGX  2018-05-03          98.1  97.69        98.23         100.6  Thu     False       N/A       N/A
#   ID        Date  Price Before  Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  UAA  2018-03-29         16.33  16.35         16.1         18.65  Thu      True         6        14
#   ID        Date  Price Before   Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  EFX  2017-09-07        138.08  139.38       120.35        143.74  Thu      True       685       685
#    ID        Date  Price Before   Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  ANTM  2015-02-04        127.94  128.58       128.19        275.54  Wed     False       N/A       N/A
#    ID       Date  Price Before  Price  Price After  Latest Price  DOW  Dropped? RecovDays RecovMean
#  EBAY  2014-5-21          21.7  21.67        21.51         40.02  Wed      True         3        69

# %%
t = Breaches(modelDays=100, predictDays=10,
             dataSource=Breaches.getEnv("DATA_SOURCE"),
             apiKey=Breaches.getEnv("ALPHA_VANTAGE_API_KEY"))

# %%
t.open(path="breaches.json", forceRemote=False)
# Out:
# Get'in Capital One [COF] ... please wait
# Get'in Target [TGT] ... please wait
# Get'in Marriott [MAR] ... please wait
# Get'in Facebook [FB] ... please wait
# Get'in T-Mobile [TMUS] ... please wait
# Get'in Quest Diagnostics [DGX] ... please wait
# Get'in Under Armour [UAA] ... please wait
# Get'in Equifax [EFX] ... please wait
# Get'in Anthem [ANTM] ... please wait
# Get'in EBAY [EBAY] ... please wait

# %%
t.predict("TGT")
# Out:
# Fit'in and predict'in TGT ... please wait

# %%
t.plot("TGT")
# Out:
#   ID        Date  Price Before  Price  Price After  Latest Price  DOW Dropped?  RecovDays  RecovMean
#  TGT  2018-12-19         64.16  61.72        60.61         63.81  Wed     True        8.0        NaN
