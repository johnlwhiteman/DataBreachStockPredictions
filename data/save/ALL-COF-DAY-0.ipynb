# %%
from Breaches import Breaches
# %matplotlib inline

# %%
b = Breaches(modelDays=1000, predictDays=None,
             dataSource=Breaches.getEnv("DATA_SOURCE"),
             apiKey=Breaches.getEnv("ALPHA_VANTAGE_API_KEY"))

# %%
b.open(path="breaches.json", forceRemote=False)
# Out:
# Get'in Anthem [ANTM] ... please wait
# Get'in Capital One [COF] ... please wait
# Get'in Equifax [EFX] ... please wait
# Get'in Facebook [FB] ... please wait
# Get'in Marriott [MAR] ... please wait
# Get'in Under Armour [UAA] ... please wait

# %%
for i in b.IDs:
    b.predict(i)
# Out:
# Fit'in and predict'in ANTM ... please wait
# Fit'in and predict'in COF ... please wait
# Fit'in and predict'in EFX ... please wait
# Fit'in and predict'in FB-2018 ... please wait
# Fit'in and predict'in MAR ... please wait
# Fit'in and predict'in UAA ... please wait

# %%
b.showMeta()
# Out:
#       ID symbol        date   price    weekday recoverNumDays  modelMean predictMean actualMean
#     ANTM   ANTM  2015-02-04  127.97  Wednesday              2      79.76      216.05     188.52
#      COF    COF  2019-07-29   98.08     Monday           None      87.01       98.34       None
#      EFX    EFX  2017-09-07  138.10   Thursday            665     110.87      168.38     116.13
#  FB-2018     FB  2018-09-28  168.84     Friday            130     148.63      182.01     165.74
#      MAR    MAR  2018-11-30  120.97     Friday             82     100.43      102.92      124.7
#      UAA    UAA  2018-03-29   16.33   Thursday              6      30.82       10.53      21.41

# %%
for i in b.IDs:
    b.plot(i)
# Out:
#    ID symbol        date   price    weekday recoverNumDays  modelMean predictMean actualMean
#  ANTM   ANTM  2015-02-04  127.97  Wednesday              2      79.76      216.05     188.52
#   ID symbol        date  price weekday recoverNumDays  modelMean predictMean actualMean
#  COF    COF  2019-07-29  98.08  Monday           None      87.01       98.34       None
#   ID symbol        date  price   weekday recoverNumDays  modelMean predictMean actualMean
#  EFX    EFX  2017-09-07  138.1  Thursday            665     110.87      168.38     116.13
#       ID symbol        date   price weekday recoverNumDays  modelMean predictMean actualMean
#  FB-2018     FB  2018-09-28  168.84  Friday            130     148.63      182.01     165.74
#   ID symbol        date   price weekday recoverNumDays  modelMean predictMean actualMean
#  MAR    MAR  2018-11-30  120.97  Friday             82     100.43      102.92      124.7
#   ID symbol        date  price   weekday recoverNumDays  modelMean predictMean actualMean
#  UAA    UAA  2018-03-29  16.33  Thursday              6      30.82       10.53      21.41
